# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")
# %matplotlib inline

# %%
data_path = "E:/web-data-mining/results/preprocessed_data.csv"
df = pd.read_csv(data_path)

# Quick look
df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  product_name  aisle_id  \
# 0         2       33120                  1          1         29760        86
# 1         2       28985                  2          1         25233        83
# 2         2        9327                  3          0         16739       104
# 3         2       45918                  4          1          9817        19
# 4         2       30035                  5          0         27101        17
#
#    department_id  aisle  department  user_id eval_set  order_number  \
# 0             16     41           7   202279    prior             3
# 1              4     53          19   202279    prior             3
# 2             13    122          16   202279    prior             3
# 3             13     89          16   202279    prior             3
# 4             13      6          16   202279    prior             3
#
#    order_dow  order_hour_of_day  days_since_prior_order  total_orders  \
# 0          5                  9                     8.0             9
# 1          5                  9                     8.0             9
# 2          5                  9                     8.0             9
# 3          5                  9                     8.0             9
# 4          5                  9                     8.0             9
#
#    avg_days_between_orders  reorder_ratio  avg_basket_size
# 0                   22.625       0.477778            11.25
# 1                   22.625       0.477778            11.25
# 2                   22.625       0.477778            11.25
# 3                   22.625       0.477778            11.25
# 4                   22.625       0.477778            11.25

# %%
#Distribution of Total Orders per User
plt.figure(figsize=(10, 4))
sns.histplot(df['total_orders'], bins=30, kde=True, color='teal')
plt.title("Distribution of Total Orders per User")
plt.xlabel("Total Orders")
plt.ylabel("User Count")
plt.show()

# %%
#Average Days Between Orders
plt.figure(figsize=(10, 4))
sns.histplot(df['avg_days_between_orders'], bins=30, kde=True, color='steelblue')
plt.title("Avg Days Between Orders (Users)")
plt.xlabel("Avg Days Between Orders")
plt.ylabel("User Count")
plt.show()

# %%
#Reorder Ratio Distribution
plt.figure(figsize=(10, 4))
sns.histplot(df['reorder_ratio'], bins=30, kde=True, color='mediumseagreen')
plt.title("User Reorder Ratio Distribution")
plt.xlabel("Reorder Ratio")
plt.ylabel("User Count")
plt.show()

# %%
#Average Basket Size per User
plt.figure(figsize=(10, 4))
sns.histplot(df['avg_basket_size'], bins=30, kde=True, color='orchid')
plt.title("Average Basket Size per User")
plt.xlabel("Avg Basket Size")
plt.ylabel("User Count")
plt.show()

# %%
#Relationship Between Basket Size and Reorder Ratio
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='avg_basket_size', y='reorder_ratio', alpha=0.4, color='coral')
plt.title("Reorder Ratio vs. Avg Basket Size")
plt.xlabel("Avg Basket Size")
plt.ylabel("Reorder Ratio")
plt.show()

# %%
#Correlation Heatmap of Engineered Features
features = ['total_orders', 'avg_days_between_orders', 'reorder_ratio', 'avg_basket_size']
corr = df[features].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, cmap='coolwarm', square=True)
plt.title("Correlation Between User-Level Features")
plt.show()
